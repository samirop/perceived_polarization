# %% [markdown]
# # Perceived Polarization
# **Important: The PerceivedPolarization.py file should be in the same folder as this notebook**

# %%
import networkx as nx

import PerceivedPolarization_v2
import numpy as np

# %%
# Create Social Network
socialnetwork = PerceivedPolarization_v2.SocialNetwork(population=20, network_type="random")

# Create Perceived Polarization Model
model = PerceivedPolarization_v2.PerceivedPolarization(socialnetwork)
model.global_perceived_opinion()

#personal_opinions = []
#for node in model.G.nodes:
#    personal_opinions.append(model.G.nodes[node]['personal_opinion'])
#print(np.mean(personal_opinions))

# Draw graph
model.draw_graph()


# Print final opinions
for node in model.G.nodes:
    print("Node", node, "personal opinion:", model.G.nodes[node]['personal_opinion'], "perceived opinion:", model.G.nodes[node]['perceived_opinion'])
# Out:
# Node 0 personal opinion: 0.4614175265208029 perceived opinion: 0.005232245546118897
# Node 1 personal opinion: -0.3206011044251884 perceived opinion: -0.11971722308991319
# Node 2 personal opinion: 0.6320147732210186 perceived opinion: -0.16193083203292924
# Node 3 personal opinion: -0.6609203087191002 perceived opinion: 0.09318232074281751
# Node 4 personal opinion: 0.021695418007608103 perceived opinion: -0.3010538298067866
# Node 5 personal opinion: 0.4664623322345183 perceived opinion: -0.16915843313511741
# Node 6 personal opinion: 0.5295549833916313 perceived opinion: -0.2683937446115641
# Node 7 personal opinion: 0.9755445752314049 perceived opinion: -0.3053828064791574
# Node 8 personal opinion: 0.9487733070925453 perceived opinion: -0.2413876175886576
# Node 9 personal opinion: 0.1222274854419565 perceived opinion: -0.14280018165035985
# Node 10 personal opinion: 0.7206459832021268 perceived opinion: -0.11179595554020959
# ...

# %%
import numpy as np

# %%
np.mean(personal_opinios)
# Out:
# -0.052261986768748436

# %%
rng = np.random.default_rng(10)

# %%
np.random.default_rng(seed=None).uniform(-1,1)
# Out:
# 0.5270505565291552

# %%
from scipy.stats import skewnorm

# %%
import matplotlib.pyplot as plt

# %%
skewnorm.rvs(1, loc=0, scale=1, size=20, random_state=None)
# Out:
# array([ 1.05985147, -0.24695589,  0.4904157 ,  0.41858836, -0.3799364 ,
#         1.55355071, -0.92402604,  1.08843888,  0.36758328, -0.07710816,
#         0.45196011,  0.36351694,  0.38828847,  1.02868278,  0.13769797,
#        -0.27421152,  2.05863448, -0.27283581,  1.61347785, -0.15483512])

# %%
help(skewnorm.rvs(-1,1))
# Out:
# Help on float64 object:
#
# class float64(floating, builtins.float)
#  |  float64(x=0, /)
#  |
#  |  Double-precision floating-point number type, compatible with Python `float`
#  |  and C ``double``.
#  |
#  |  :Character code: ``'d'``
#  |  :Canonical name: `numpy.double`
#  |  :Alias: `numpy.float_`
#  |  :Alias on this platform (win32 AMD64): `numpy.float64`: 64-bit precision floating-point number type: sign bit, 11 bits exponent, 52 bits mantissa.
#  |
#  |  Method resolution order:
#  |      float64
#  |      floating
#  |      inexact
#  |      number
#  |      generic
#  |      builtins.float
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __abs__(self, /)
#  |      abs(self)
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __bool__(self, /)
#  |      True if self else False
#  |
#  |  __divmod__(self, value, /)
#  |      Return divmod(self, value).
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
# ...

# %%
skew = skewnorm.rvs(1, loc=-0.4, scale=0.5, size=2000, random_state=None)

def bound_value(x):
    if x>1:
        return 1
    elif x<-1:
        return -1
    else:
        return x

plt.hist(np.vectorize(bound_value)(skew),bins=200)
plt.show()

# %%
test = rng.normal(0,0.3,size=1000)

# %%
def bound_value(x):
    if x>1:
        return 1
    elif x<-1:
        return -1
    else:
        return x

# %%
plt.hist(np.vectorize(bound_value)(test),bins=200)
plt.show()

# %%
dict(enumerate(np.sort(np.vectorize(bound_value)(rng.normal(0,0.2,size=50)))))
# Out:
# {0: -0.3264427707186116,
#  1: -0.24885068555191414,
#  2: -0.24557690126822806,
#  3: -0.23380127077301657,
#  4: -0.21797992334320104,
#  5: -0.21038604798719251,
#  6: -0.19645378347548295,
#  7: -0.19567712848461363,
#  8: -0.18765548067620805,
#  9: -0.17641465811992352,
#  10: -0.16898145374912732,
#  11: -0.15948109220486573,
#  12: -0.09831951950419368,
#  13: -0.0905486337974608,
#  14: -0.08986644322792249,
#  15: -0.06477684029593372,
#  16: -0.05830085071499496,
#  17: -0.04547098709635035,
#  18: -0.04152526301308024,
#  19: -0.03702446639543096,
#  20: -0.026756996213589748,
#  21: -0.01141882809436622,
#  22: 0.0014003706111809673,
#  23: 0.0021195175685870737,
#  24: 0.0034091702293696674,
#  25: 0.03479698010275125,
#  26: 0.057183273452963305,
#  27: 0.07419493635734659,
#  28: 0.08911774982113385,
#  29: 0.11942083469527501,
#  30: 0.12618207621361469,
#  31: 0.13774185621569496,
#  32: 0.14034728478936265,
#  33: 0.16569353438427425,
#  34: 0.18755726940881345,
# ...

# %%
nx.get_node_attributes(model.G,'personal_opinion')
# Out:
# {0: 0.4614175265208029,
#  1: -0.3206011044251884,
#  2: 0.6320147732210186,
#  3: -0.6609203087191002,
#  4: 0.021695418007608103,
#  5: 0.4664623322345183,
#  6: 0.5295549833916313,
#  7: 0.9755445752314049,
#  8: 0.9487733070925453,
#  9: 0.1222274854419565,
#  10: 0.7206459832021268,
#  11: -0.43213412434315845,
#  12: -0.9735016858832897,
#  13: -0.3328287339915357,
#  14: -0.9713816973928915,
#  15: -0.6911800806604278,
#  16: -0.794412722248395,
#  17: -0.6416427525882844,
#  18: 0.23195136871214572,
#  19: -0.8987298670912183}

# %%
nx.stochastic_block_model()
